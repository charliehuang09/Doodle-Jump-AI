# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
max_plot = np.load('/Users/USER/ML/max.npy')
mean_plot = np.load('/Users/USER/ML/mean.npy')

# %%
plt.plot(max_plot)

# %%
plt.plot(mean_plot)

# %%
print(max(max_plot), max(mean_plot))
# Out:
# 464.0 10.702

# %%
for i in range(len(mean_plot)):
    mean_plot[i] = np.mean(mean_plot[i:i+50])
for i in range(len(max_plot)):
    max_plot[i] = np.mean(max_plot[i:i+50])

# %%
plt.plot(mean_plot)
plt.plot(max_plot)
plt.legend(['Mean Plot', 'Max Plot'])
